# %% [markdown]
# # 📉 Previsão de Churn em Telecom
#
# Notebook do projeto de previsão de churn. Executa a geração de dados, a análise exploratória e a modelagem, exibindo os gráficos ao final.

# %% [markdown]
# ## 1. Execução do pipeline

# %%
# %run src/01_gerar_dados.py
# Out:
# Dados gerados: C:\Users\kalux\OneDrive\Área de Trabalho\portfolio-dados\1-churn-telecom\dados\clientes_telecom.csv  (7000 linhas, churn=24.0%)

# %%
# %run src/02_analise_eda.py
# Out:
# Resumo estatístico:
#         id_cliente    idade  tempo_casa_meses  mensalidade  reclamacoes_6m  \
# count     7000.00  7000.00           7000.00      7000.00         7000.00
# mean      3500.50    48.35             36.17        69.76            1.21
# std       2020.87    17.74             20.79        24.56            1.10
# min          1.00    18.00              1.00        20.00            0.00
# 25%       1750.75    33.00             18.00        52.95            0.00
# 50%       3500.50    48.00             36.00        69.12            1.00
# 75%       5250.25    64.00             54.00        86.20            2.00
# max       7000.00    79.00             72.00       150.00            6.00
#
#          churn
# count  7000.00
# mean      0.24
# std       0.43
# min       0.00
# 25%       0.00
# 50%       0.00
# 75%       0.00
# max       1.00
#
# Taxa de churn: 24.0%
# ...

# %%
# %run src/03_modelagem.py
# Out:
# === Regressão Logística (AUC=0.838) ===
#               precision    recall  f1-score   support
#
#            0      0.839     0.944     0.888      1331
#            1      0.704     0.425     0.530       419
#
#     accuracy                          0.819      1750
#    macro avg      0.771     0.684     0.709      1750
# weighted avg      0.807     0.819     0.802      1750
# === Random Forest (AUC=0.792) ===
#               precision    recall  f1-score   support
#
#            0      0.834     0.918     0.874      1331
#            1      0.616     0.418     0.498       419
#
#     accuracy                          0.798      1750
#    macro avg      0.725     0.668     0.686      1750
# weighted avg      0.782     0.798     0.784      1750
#
#
# >>> Melhor modelo: Regressão Logística (AUC=0.838)
# Gráficos de avaliação salvos em C:\Users\kalux\OneDrive\Área de Trabalho\portfolio-dados\1-churn-telecom\imagens

# %% [markdown]
# ## 2. Resultados visuais

# %%
from IPython.display import Image, display
display(Image("imagens/churn_por_contrato.png"))
display(Image("imagens/tempo_casa_churn.png"))
display(Image("imagens/correlacao.png"))
display(Image("imagens/matriz_confusao.png"))
display(Image("imagens/curva_roc.png"))
